# %%
import requests
from bs4 import BeautifulSoup
import re
import threading
from datetime import datetime
import pandas as pd
import time

# %%
url = "https://www.google.com/search?q=ganjar+::+tribunnews&sca_esv=729edc120b86c4d9&tbs=cdr:1,cd_min:1/15/2024,cd_max:1/15/2024&tbm=nws&sxsrf=ACQVn0-8w6sVlWNb9v7tvErLJSqrGoetzw:1706603671648&ei=l7S4ZbCaJ-Ga4-EPh8qu2Ac&start=0&sa=N&ved=2ahUKEwjwwfuM2oSEAxVhzTgGHQelC3s4PBDy0wN6BAgEEAQ&biw=1366&bih=654&dpr=1"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="id"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>ganjar :: tribunnews - Penelusuran Google</title><script nonce="ZjNZsDhqjv9aD4EJuFZdJQ">(function(){
# ...

# %%
articles = soup.find_all('div', {"class": "Gx5Zad fP1Qef xpd EtOod pkphOe"})
for article in articles:
    link = article.find('a')['href']
    print(link)
# Out:
# /url?q=https://www.tribunnews.com/mata-lokal-memilih/2024/01/30/yenny-wahid-tren-survei-prabowo-turun-ganjar-naik&sa=U&ved=2ahUKEwiVvI7b4YSEAxXrxjgGHenTBV0QxfQBegQIBxAC&usg=AOvVaw1-q73vx04CjsQyE2nRh9Af
# /url?q=https://www.tribunnews.com/mata-lokal-memilih/2024/01/28/ganjar-bareng-megawati-kampanye-akbar-di-medan-dan-yogyakarta-hari-ini&sa=U&ved=2ahUKEwiVvI7b4YSEAxXrxjgGHenTBV0QxfQBegQICRAC&usg=AOvVaw0vip-EFe6zqzO8iQVnf-ap
# /url?q=https://www.tribunnews.com/mata-lokal-memilih/2024/01/29/tpn-ganjar-mahfud-serukan-masyarakat-tolak-dinasti-politik&sa=U&ved=2ahUKEwiVvI7b4YSEAxXrxjgGHenTBV0QxfQBegQIABAC&usg=AOvVaw2ypP_pISshonVrUM5CINDy
# /url?q=https://video.tribunnews.com/view/695013/ganjar-mahfud-hadiri-warung-d3mokrasi-di-amerika-serikat-acara-digelar-di-5-kota-secara-serentak&sa=U&ved=2ahUKEwiVvI7b4YSEAxXrxjgGHenTBV0QxfQBegQICBAC&usg=AOvVaw2Q17cInUZpJevvMv8QPoMD
# ...

# %%
# import mechanicalsoup

# # Create a Browser object
# browser = mechanicalsoup.Browser()

# # Specify the URL of the webpage you want to scrape
# url = "https://www.google.com/search?q=ganjar+::+tribunnews&sca_esv=729edc120b86c4d9&tbs=cdr:1,cd_min:1/15/2024,cd_max:1/15/2024&tbm=nws&sxsrf=ACQVn098j05T6oxrzqg5oovlwz5QSvu38g:1706603595333&ei=S7S4ZYHzE7uR4-EPq5CB2Ak&start=70&sa=N&ved=2ahUKEwjBxMno2YSEAxW7yDgGHStIAJsQ8tMDegQIBBAQ&biw=1366&bih=654&dpr=1"

# # Use the Browser to open the URL
# response = browser.get(url)

# # Check if the request was successful (status code 200)
# if response.status_code == 200:
#     # Print the HTML content of the page
#     print(response.text)
# else:
#     print(f"Failed to fetch the webpage. Status code: {response.status_code}")
