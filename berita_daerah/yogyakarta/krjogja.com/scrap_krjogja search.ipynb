# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from datetime import datetime
import threading

# %%
jumlah_index = 70
threads_link = []
links = []
results = []
threads = []
keywords = 'ganjar'

# %%
def scrape_links(page_number,keywords):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36'
    }
    url = f"https://www.krjogja.com/search?q={keywords}&page={page_number}"
    response = requests.get(url,headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    articles = soup.find_all('h2',{"class": "latest__title"})
    
    page_links = []
    for article in articles:
        link = article.find('a')['href']
        page_links.append(link)
    
    print(f"Scraped {len(page_links)} links from page {page_number}")
    return page_links

# %%
for page_number in range(1, jumlah_index + 1):
    thread = threading.Thread(target=lambda p=page_number: links.extend(scrape_links(p,keywords)))
    thread.start()
    threads_link.append(thread)

for thread in threads_link:
    thread.join()
print("Total Links:", len(links))
# Out:
# Scraped 10 links from page 1
# Scraped 10 links from page 2
# Scraped 10 links from page 7
# Scraped 10 links from page 12
# Scraped 10 links from page 15
# Scraped 10 links from page 34
# Scraped 10 links from page 17
# Scraped 10 links from page 11
# Scraped 10 links from page 6
# Scraped 10 links from page 39
# Scraped 10 links from page 3
# Scraped 10 links from page 13
# Scraped 10 links from page 26
# Scraped 10 links from page 8
# Scraped 10 links from page 21
# Scraped 10 links from page 23
# Scraped 10 links from page 31
# Scraped 10 links from page 20
# Scraped 10 links from page 14
# Scraped 10 links from page 43
# Scraped 10 links from page 24
# Scraped 10 links from page 22
# Scraped 10 links from page 40
# Scraped 10 links from page 9
# Scraped 10 links from page 5
# Scraped 10 links from page 10
# Scraped 10 links from page 36
# Scraped 10 links from page 35
# Scraped 10 links from page 37
# Scraped 10 links from page 18
# Scraped 10 links from page 27
# Scraped 10 links from page 54
# Scraped 10 links from page 16
# Scraped 10 links from page 30
# Scraped 10 links from page 32
# Scraped 10 links from page 57
# Scraped 10 links from page 28
# Scraped 10 links from page 41
# Scraped 10 links from page 45
# Scraped 10 links from page 59
# Scraped 10 links from page 55
# Scraped 10 links from page 67
# Scraped 10 links from page 29
# Scraped 1 links from page 70
# Scraped 10 links from page 50
# Scraped 10 links from page 33
# Scraped 10 links from page 47
# Scraped 10 links from page 69
# Scraped 10 links from page 56
# Scraped 10 links from page 60
# Scraped 10 links from page 61
# Scraped 10 links from page 65
# Scraped 10 links from page 48
# Scraped 10 links from page 49
# Scraped 10 links from page 64
# Scraped 10 links from page 19
# Scraped 10 links from page 53
# Scraped 10 links from page 58
# Scraped 10 links from page 51
# Scraped 10 links from page 63
# Scraped 10 links from page 66
# Scraped 10 links from page 42
# Scraped 10 links from page 44
# Scraped 10 links from page 38
# Scraped 10 links from page 25
# Scraped 10 links from page 62
# Scraped 10 links from page 46
# Scraped 10 links from page 68
# Scraped 10 links from page 52
# Scraped 10 links from page 4
# Total Links: 691

# %%
def scrape_url(url,keywords):
    try:
        headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36'
        }
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            
            # Judul Berita
            title_elem = soup.find('h1',{"class": "read__title"})
            if title_elem:
                title_text = title_elem.text
            else:
                title_text = "Title not found"
            # # Author berita
            author_elem = soup.find('div', {"class": "read__info__author"})
            if author_elem:
                penulis = author_elem.find('a')
                author_text =penulis.text
            else:
                author_text = "Author not found"
            
            # # tanggal berita
            date_elem = soup.find('div', {"class": "read__info__date"})
            if date_elem:
                date_text = date_elem.text
            else:
                date_text = "Date not found"
            #     # Category berita
            category_elements = soup.find_all('li', {"class": "breadcrumb__item"})
            if category_elements:
                category_text= category_elements[1].text
            else:
                category_text = "Category not found"
            # ## Content Berita
            body_elem = soup.find('article', {"class": "read__content clearfix"})
            
            if body_elem:
                content_elem = body_elem.find_all('p')
                content_text = ""
                for p in content_elem:
                    content_text += p.text.strip() + "\n"
                
                if content_text.strip():
                    content_text=content_text
                else:
                    content_text ="Content not found"
            else:
              content_text ="Content not found"

            results.append({'title': title_text,
                            'keywords':keywords,
                            'author': author_text,
                            'date':date_text,
                            'category': category_text,
                            'content': content_text,
                            'region':'jogja',
                            'nama_berita' : 'krjogja',
                            'link' : url})
        else:
            print(f"Failed to retrieve data from {url}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL '{url}': {e}")
    except Exception as e:
        print(f"Error processing URL '{url}': {e}")

# %%
for url in links:
    thread = threading.Thread(target=scrape_url, args=(url,keywords))
    thread.start()
    threads.append(thread)
    
for thread in threads:
    thread.join()
# Out:
# Failed to retrieve data from https://www.krjogja.com/nasional/1242451685/-minum-kopi-bareng-cara-ganjar-pranowo-serap-langsung-aspirasi-warga-
# Failed to retrieve data from https://www.krjogja.com/nasional/1242449696/pdip-pertimbangkan-nasaruddin-umar-cawapres-ganjar
# Failed to retrieve data from https://www.krjogja.com/nasional/1242465990/psi-usung-ganjar-pranowo-pdip-ingatkan-etika-politik
# Failed to retrieve data from https://www.krjogja.com/nasional/1242950108/bacapres-ganjar-pranowo-janjikan-gaji-guru-rp30-juta-ini-kata-pengamat

# %%
df = pd.DataFrame(results)
print("Total Links:", len(results))
df.head(10)
# Out:
# Total Links: 687
#                                                title keywords  \
# 0            Peluang Duet Ganjar - Prabowo Tertutup    ganjar
# 1   Ganjar Pranowo Ungkap Strategi Majukan UMKM s...   ganjar
# 2    Arsjad Rasjid Bocorkan Akan Ada Tambahan Per...   ganjar
# 3   Menangkan Ganjar, PDIP Kota Yogya Rekrut Gen ...   ganjar
# 4   Hoaks Gizi dan Kesehatan Bisa Berdampak Buruk...   ganjar
# 5   DPC PDI P  Bantul Gelar Senam di 17 Kecamatan...   ganjar
# 6   Rapimda Jaman DIY Panaskan Mesin Siap Menangk...   ganjar
# 7       Emak-emak Sragen Gaungkan 'Ganjar Presiden'    ganjar
# 8   Begini Pesan Megawati ke Kader PDIP: Elektabi...   ganjar
# 9   Santri Tahfiz dan Warga di Yogyakarta Doakan ...   ganjar
#
#                author                                               date  \
# 0       admin krjogja  \n                                    - Selasa...
# 1      Tomi Sujatmiko  \n                                    - Minggu...
# 2      Tomi Sujatmiko  \n                                    - Senin,...
# 3  Primaswolo Sudjono  \n                                    - Kamis,...
# 4      Tomi Sujatmiko  \n                                    - Rabu, ...
# 5        Sukro Riyadi  \n                                    - Minggu...
# 6         Ivan Aditya  \n                                    - Sabtu,...
# 7       Said Masykuri  \n                                    - Sabtu,...
# 8      Tomi Sujatmiko  \n                                    - Senin,...
# 9         Ivan Aditya  \n                                    - Kamis,...
#
#        category                                            content region  \
# 0    Nasional\n  \nJAKARTA - Sufmi Dasco Ahmad yang menjabat Ke...  jogja
# 1    Nasional\n  Krjogja.com - Jakarta - Bakal Calon Presiden (...  jogja
# 2    Nasional\n  Krjogja.com -Jakarta - Ketua Tim Pemenangan Na...  jogja
# 3  Yogyakarta\n  \nKrjogja.com - YOGYA - Guna meraih suara Ganj...  jogja
# 4      Sleman\n  Krjoga.com - SLEMAN - Siti Atikoh Supriyanti m...  jogja
# 5      Bantul\n                                  Content not found  jogja
# 6  Yogyakarta\n  \nKrjogja.com - YOGYA - Pengurus Dewan Pimpina...  jogja
# 7        Solo\n                                  Content not found  jogja
# 8    Nasional\n  Krjogja.com - Jakarta - Ketua Umum PDI Perjuan...  jogja
# 9      Sleman\n  \n\nKrjogja.com - SLEMAN - Warga dan para sant...  jogja
#
#   nama_berita                                               link
# 0     krjogja  https://www.krjogja.com/nasional/1243039538/pe...
# 1     krjogja  https://www.krjogja.com/nasional/1243053032/ga...
# 2     krjogja  https://www.krjogja.com/nasional/1243035525/ar...
# 3     krjogja  https://www.krjogja.com/yogyakarta/1243068970/...
# 4     krjogja  https://www.krjogja.com/sleman/1243063064/hoak...
# 5     krjogja  https://www.krjogja.com/bantul/1243053796/dpc-...
# 6     krjogja  https://www.krjogja.com/yogyakarta/1243031823/...
# 7     krjogja  https://www.krjogja.com/solo/1243052345/emak-e...
# 8     krjogja  https://www.krjogja.com/nasional/1243034989/be...
# 9     krjogja  https://www.krjogja.com/sleman/1243045817/sant...

# %%
filtered_df = df[df['content'].str.contains(keywords, case=False)|
                 df['title'].str.contains(keywords, case=False)]
print('hasil filter',len(filtered_df))
filtered_df.head(10)
# Out:
# hasil filter 687
#                                                title keywords  \
# 0            Peluang Duet Ganjar - Prabowo Tertutup    ganjar
# 1   Ganjar Pranowo Ungkap Strategi Majukan UMKM s...   ganjar
# 2    Arsjad Rasjid Bocorkan Akan Ada Tambahan Per...   ganjar
# 3   Menangkan Ganjar, PDIP Kota Yogya Rekrut Gen ...   ganjar
# 4   Hoaks Gizi dan Kesehatan Bisa Berdampak Buruk...   ganjar
# 5   DPC PDI P  Bantul Gelar Senam di 17 Kecamatan...   ganjar
# 6   Rapimda Jaman DIY Panaskan Mesin Siap Menangk...   ganjar
# 7       Emak-emak Sragen Gaungkan 'Ganjar Presiden'    ganjar
# 8   Begini Pesan Megawati ke Kader PDIP: Elektabi...   ganjar
# 9   Santri Tahfiz dan Warga di Yogyakarta Doakan ...   ganjar
#
#                author                                               date  \
# 0       admin krjogja  \n                                    - Selasa...
# 1      Tomi Sujatmiko  \n                                    - Minggu...
# 2      Tomi Sujatmiko  \n                                    - Senin,...
# 3  Primaswolo Sudjono  \n                                    - Kamis,...
# 4      Tomi Sujatmiko  \n                                    - Rabu, ...
# 5        Sukro Riyadi  \n                                    - Minggu...
# 6         Ivan Aditya  \n                                    - Sabtu,...
# 7       Said Masykuri  \n                                    - Sabtu,...
# 8      Tomi Sujatmiko  \n                                    - Senin,...
# 9         Ivan Aditya  \n                                    - Kamis,...
#
#        category                                            content region  \
# 0    Nasional\n  \nJAKARTA - Sufmi Dasco Ahmad yang menjabat Ke...  jogja
# 1    Nasional\n  Krjogja.com - Jakarta - Bakal Calon Presiden (...  jogja
# 2    Nasional\n  Krjogja.com -Jakarta - Ketua Tim Pemenangan Na...  jogja
# 3  Yogyakarta\n  \nKrjogja.com - YOGYA - Guna meraih suara Ganj...  jogja
# 4      Sleman\n  Krjoga.com - SLEMAN - Siti Atikoh Supriyanti m...  jogja
# 5      Bantul\n                                  Content not found  jogja
# 6  Yogyakarta\n  \nKrjogja.com - YOGYA - Pengurus Dewan Pimpina...  jogja
# 7        Solo\n                                  Content not found  jogja
# 8    Nasional\n  Krjogja.com - Jakarta - Ketua Umum PDI Perjuan...  jogja
# 9      Sleman\n  \n\nKrjogja.com - SLEMAN - Warga dan para sant...  jogja
#
#   nama_berita                                               link
# 0     krjogja  https://www.krjogja.com/nasional/1243039538/pe...
# 1     krjogja  https://www.krjogja.com/nasional/1243053032/ga...
# 2     krjogja  https://www.krjogja.com/nasional/1243035525/ar...
# 3     krjogja  https://www.krjogja.com/yogyakarta/1243068970/...
# 4     krjogja  https://www.krjogja.com/sleman/1243063064/hoak...
# 5     krjogja  https://www.krjogja.com/bantul/1243053796/dpc-...
# 6     krjogja  https://www.krjogja.com/yogyakarta/1243031823/...
# 7     krjogja  https://www.krjogja.com/solo/1243052345/emak-e...
# 8     krjogja  https://www.krjogja.com/nasional/1243034989/be...
# 9     krjogja  https://www.krjogja.com/sleman/1243045817/sant...

# %%
current_datetime = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
excel_file_name = f'../../tempat_hasil_daerah/jogja_krjogja_{keywords}_{current_datetime}.xlsx'
df.to_excel(excel_file_name, index=False)

print(f'Data has been saved to {excel_file_name}')
# Out:
# Data has been saved to ../../tempat_hasil_daerah/jogja_krjogja_ganjar_2023-10-12_18-15-54.xlsx
